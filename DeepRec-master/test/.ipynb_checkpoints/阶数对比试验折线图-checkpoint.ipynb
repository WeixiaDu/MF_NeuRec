# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib.pyplot import MultipleLocator
# %matplotlib inline

# %%
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
plt.rc('axes', axisbelow=True)# 背景线放底层
myfont = fm.FontProperties(fname=r'F:/jupyter_train/simhei.ttf')
# plt.rcParams['font.sans-serif'] = ['SimSun']

# %%
# NMI
y1 = [92.3,  92.82, 93.69, 93.21, 93.07]    # GAT
y2 = [92.07, 92.44, 93.07, 92.54, 92.17]    # GCN
y3 = [91.97, 92.17, 93.82, 92.66,  92.82]    # HAN
y4 = [92.33, 92.88, 92.67, 92.84, 92.88]    # GTN
y5 = [96.33, 93.88, 94.67, 91.84, 92.54]    # SimGAT
ylabel = np.array([91.5,92,92.5,93,93.5,94])
label = '阶数'


# ARI
# y1 = [92.3,  92.82, 93.69, 93.21]    # GAT
# y2 = [92.07, 92.44, 93.07, 92.54]    # GCN
# y3 = [91.97, 92.17, 93.82, 92.66]    # HAN
# y4 = [92.33, 92.88, 92.67, 92.84]    # GTN
# y5 = [92.33, 92.88, 92.67, 92.84]    # SimGAT
# ylabel = np.array([59,59.5,60,60.5,61,61.5,62,62.5,63,63.5])
# label = 'IMDB'


# FMI
# y1 = [92.3,  92.82, 93.69, 93.21]    # GAT
# y2 = [92.07, 92.44, 93.07, 92.54]    # GCN
# y3 = [91.97, 92.17, 93.82, 92.66]    # HAN
# y4 = [92.33, 92.88, 92.67, 92.84]    # GTN
# y5 = [92.33, 92.88, 92.67, 92.84]    # SimGAT
# ylabel = np.array([41,41.5,42,42.5,43,43.5,44,44.5])
# label = 'HUAWEI'

# %%
xlabel = np.array([r'$1$','$2$','$3$','$4$','$5$'])
font1 = {
'size'   : 16
}
myfont = fm.FontProperties(fname=r'F:/jupyter_train/simhei.ttf')

plt.figure(figsize=(12, 7))
plt.tick_params(labelsize=16)


plt.plot(xlabel,y1,marker='*',color='r',label='GAT')
plt.plot(xlabel,y3,marker='+',color='b',label='GCN')
plt.plot(xlabel,y2,marker='o',color='c',linestyle='--',label='HAN')
plt.plot(xlabel,y4,marker='v',color='m',linestyle='-.',label='GTN')
plt.plot(xlabel,y5,marker='^',color='y',linestyle=':',label='SimGAT')


plt.yticks(ylabel)
plt.xticks(size=18)

#plt.grid(ls='--',axis='y')



plt.xlabel(u'阶数',  fontproperties=myfont,size=26) 
plt.ylabel('NMI',size=26)
# plt.ylabel('ARI',size=26)
# plt.ylabel('FMI',size=26)

#plt.legend(loc='lower right',prop=font1)

name = label+'.png'
#plt.savefig(name, dpi = 300, bbox_inches = 'tight')
plt.show()
